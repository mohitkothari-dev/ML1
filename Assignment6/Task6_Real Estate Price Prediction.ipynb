# %% [markdown]
# # Task6: Predicting Real Estate House Prices

# %% [markdown]
# ## This task is provided to test your understanding of building a Linear Regression model for a provided dataset

# %% [markdown]
# ### Dataset: Real_estate.csv

# %% [markdown]
# ### Import the necessary libraries
# #### Hint: Also import seaborn

# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Read the csv data into a pandas dataframe and display the first 5 samples

# %%
hp = pd.read_csv('Real estate.csv')
hp.head()
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1             2012.917          32.0
# 1   2             2012.917          19.5
# 2   3             2013.583          13.3
# 3   4             2013.500          13.3
# 4   5             2012.833           5.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2
# 2     24.98746     121.54391                        47.3
# ...

# %% [markdown]
# ### Show more information about the dataset

# %%
hp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 414 entries, 0 to 413
# Data columns (total 8 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   No                                      414 non-null    int64
#  1   X1 transaction date                     414 non-null    float64
#  2   X2 house age                            414 non-null    float64
#  3   X3 distance to the nearest MRT station  414 non-null    float64
#  4   X4 number of convenience stores         414 non-null    int64
#  5   X5 latitude                             414 non-null    float64
#  6   X6 longitude                            414 non-null    float64
#  7   Y house price of unit area              414 non-null    float64
# dtypes: float64(6), int64(2)
# memory usage: 26.0 KB

# %% [markdown]
# ### Find how many samples are there and how many columns are there in the dataset

# %%
hp.shape
# Out:
# (414, 8)

# %% [markdown]
# ### What are the features available in the dataset?

# %%
hp.columns  #feature means columns
# Out:
# Index(['No', 'X1 transaction date', 'X2 house age',
#        'X3 distance to the nearest MRT station',
#        'X4 number of convenience stores', 'X5 latitude', 'X6 longitude',
#        'Y house price of unit area'],
#       dtype='object')

# %% [markdown]
# ### Check if any features have missing data

# %%
hp.isnull().sum(axis=0)
# Out:
# No                                        0
# X1 transaction date                       0
# X2 house age                              0
# X3 distance to the nearest MRT station    0
# X4 number of convenience stores           0
# X5 latitude                               0
# X6 longitude                              0
# Y house price of unit area                0
# dtype: int64

# %% [markdown]
# ### Group all the features as dependent features in X

# %%
X = hp.iloc[:, :-1]
X
# Out:
#       No  X1 transaction date  X2 house age  \
# 0      1             2012.917          32.0
# 1      2             2012.917          19.5
# 2      3             2013.583          13.3
# 3      4             2013.500          13.3
# 4      5             2012.833           5.0
# ..   ...                  ...           ...
# 409  410             2013.000          13.7
# 410  411             2012.667           5.6
# 411  412             2013.250          18.8
# 412  413             2013.000           8.1
# 413  414             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# ...

# %% [markdown]
# ### Group feature(s) as independent features in y

# %%
y = hp.iloc[:,-1]
y
# Out:
# 0      37.9
# 1      42.2
# 2      47.3
# 3      54.8
# 4      43.1
#        ...
# 409    15.4
# 410    50.0
# 411    40.6
# 412    52.5
# 413    63.9
# Name: Y house price of unit area, Length: 414, dtype: float64

# %% [markdown]
# ### Split the dataset into train and test data

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05, random_state=42)

# %% [markdown]
# ### Choose the model (Linear Regression)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %% [markdown]
# ### Create an Estimator object

# %%
hp_reg = LinearRegression()

# %% [markdown]
# ### Train the model

# %%
hp_reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Apply the model

# %%
hp_predict = hp_reg.predict(X_test)
hp_predict
# Out:
# array([47.37324517, 40.67490479, 43.38252   , 39.2288875 , 26.80886894,
#        45.52710831, 44.23554581, 46.4223488 , 24.3551168 , 54.81551634,
#        34.26610156, 36.72006427, 36.600396  , 24.15337694, 35.39022958,
#        33.58654479, 43.92244407, 45.30005946, 29.40294769, 44.6910531 ,
#         1.18828452])

# %% [markdown]
# ### Display the coefficients

# %%
hp_reg.coef_
# Out:
# array([-3.92174168e-03,  5.37381113e+00, -2.70428680e-01, -4.71459414e-03,
#         1.10223141e+00,  2.10493682e+02, -1.93197441e+01])

# %% [markdown]
# ### Find how well the trained model did with testing data

# %%
print("r2 Score: %.2f" % r2_score(y_test, hp_predict))
# Out:
# r2 Score: 0.65

# %% [markdown]
# ### Plot House Age Vs Price
# #### Hint: Use regplot in sns

# %%
sns.regplot(x=hp['X2 house age'], y=hp['Y house price of unit area'])
# Out:
# <AxesSubplot:xlabel='X2 house age', ylabel='Y house price of unit area'>

# %% [markdown]
# ### Plot Distance to MRT station Vs Price

# %%
sns.regplot(x=hp['Y house price of unit area'], y=hp['X3 distance to the nearest MRT station'])
# Out:
# <AxesSubplot:xlabel='Y house price of unit area', ylabel='X3 distance to the nearest MRT station'>

# %% [markdown]
# ### Plot Number of Convienience Stores Vs Price

# %%
sns.regplot(x=hp['Y house price of unit area'], y=hp['X4 number of convenience stores'])
# Out:
# <AxesSubplot:xlabel='Y house price of unit area', ylabel='X4 number of convenience stores'>
